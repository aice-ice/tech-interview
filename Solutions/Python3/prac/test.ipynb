# %%
list("abcdefg")
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
list("aabb")
# Out:
# ['a', 'a', 'b', 'b']

# %%
for i, m in enumerate(list("aabb")):
    if m not in list("aabb")[i+1:]:
        print(m)
# Out:
# a
# b

# %%
l = list("aabb")
l[0] not in l[1:]
# Out:
# False

# %%
import collections
import heapq

# %%
a = collections.Counter("aabb")

a[]
# Out:
#   Cell In[14], line 3
#     a[]
#       ^
# SyntaxError: invalid syntax

# %%
nums = [1, -1, 0]
k = 0

ref = collections.Counter(nums)
c = ref[k]

for i in range(len(nums)-1):
    if k==nums[i]+nums[i+1]:
        c += 1

c
# Out:
# 2

# %%
n = collections.defaultdict(lambda: 1)
n["a"] += 1

n
# Out:
# defaultdict(<function __main__.<lambda>()>, {'a': 2})

# %%
l = [1, 2, 3, 4, 5]

for i, n in enumerate(l):
    print(i, n)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5}

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
type(set(l))
# Out:
# set

# %%
nums = [1,1,1,2,2,3]
c = collections.Counter(nums)

heapq.nlargest(2, c.items())
# Out:
# [(3, 1), (2, 2)]

# %%
a = collections.defaultdict(int)
a[0] = 0

max(a)
# Out:
# 0
